# %% [markdown]
# # Filtering

# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/Political Dynasty v9.csv")
df
# Out:
#        Last Name  First Name  Middle Name   Position      Party  Year  \
# 0         ACOSTA  CHERRY PIE  BALLESTEROS  COUNCILOR         LP  2004
# 1          OLVIS    ANACLETO        HAMOY      MAYOR       PDSP  2004
# 2       LACAMBRA       PRIMO        PABLO  COUNCILOR        NPC  2004
# 3       HALLAZGO     EMEDIOS       MARBAN  COUNCILOR  LAKAS-CMD  2004
# 4         LABUNI       EDGAR         TELA  COUNCILOR        NPC  2004
# ...          ...         ...          ...        ...        ...   ...
# 122362  BAUTISTA      EVELYN     SOMBILLA  COUNCILOR      LAKAS  2022
# 122363  ESPINOZA     MARIBEL     REALISTA  COUNCILOR        IND  2022
# 122364  CAHATIAN       JOPIE     LINGGAYA  COUNCILOR      LAKAS  2022
# 122365    DELOSO       MOMAR        ACDOG  COUNCILOR     HUGPNG  2022
# 122366  CALLUENG     CONRADO      RUMUSUD  COUNCILOR     PDPLBN  2022
#
#                    Province       Region  Position Weight  \
# 0                   PALAWAN  REGION IV-B                2
# 1       ZAMBOANGA DEL NORTE    REGION IX                5
# 2                PANGASINAN     REGION I                2
# 3          MISAMIS ORIENTAL     REGION X                2
# 4                   CAGAYAN    REGION II                2
# ...                     ...          ...              ...
# 122362      SURIGAO DEL SUR  REGION XIII                2
# 122363      SURIGAO DEL SUR  REGION XIII                2
# 122364      SURIGAO DEL SUR  REGION XIII                2
# 122365      SURIGAO DEL SUR  REGION XIII                2
# 122366              CAGAYAN    REGION II                2
#
#                             Full Name  Community
# 0       CHERRY PIE BALLESTEROS ACOSTA         10
# 1                ANACLETO HAMOY OLVIS          0
# 2                PRIMO PABLO LACAMBRA         63
# 3             EMEDIOS MARBAN HALLAZGO         15
# 4                   EDGAR TELA LABUNI        213
# ...                               ...        ...
# 122362       EVELYN SOMBILLA BAUTISTA        207
# 122363      MARIBEL REALISTA ESPINOZA         15
# 122364        JOPIE LINGGAYA CAHATIAN        208
# 122365             MOMAR ACDOG DELOSO         26
# 122366       CONRADO RUMUSUD CALLUENG          0
#
# [122367 rows x 11 columns]

# %%
df[df["Last Name"] == "PATAYAN"]
# Out:
#        Last Name First Name Middle Name    Position   Party  Year Province  \
# 9419     PATAYAN      EDANO     TUCRANG  VICE MAYOR     NPC  2004   APAYAO
# 64953    PATAYAN     EDAÃ‘O         NaN   COUNCILOR      NP  2013   APAYAO
# 78642    PATAYAN     EDAÃ‘O         NaN   COUNCILOR      LP  2016   APAYAO
# 102199   PATAYAN      EDAÑO     TUCRANG   COUNCILOR  PDPLBN  2019   APAYAO
#
#                                   Region  Position Weight  \
# 9419    CORDILLERA ADMINISTRATIVE REGION                3
# 64953   CORDILLERA ADMINISTRATIVE REGION                2
# 78642   CORDILLERA ADMINISTRATIVE REGION                2
# 102199                               NaN                2
#
#                     Full Name  Community
# 9419    EDANO TUCRANG PATAYAN         95
# 64953         EDAÃ‘O  PATAYAN         79
# 78642         EDAÃ‘O  PATAYAN         75
# 102199  EDAÑO TUCRANG PATAYAN         71

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122367 entries, 0 to 122366
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Last Name        122367 non-null  object
#  1   First Name       122367 non-null  object
#  2   Middle Name      108186 non-null  object
#  3   Position         122367 non-null  object
#  4   Party            121237 non-null  object
#  5   Year             122367 non-null  int64
#  6   Province         122367 non-null  object
#  7   Region           104233 non-null  object
#  8   Position Weight  122367 non-null  int64
#  9   Full Name        122367 non-null  object
#  10  Community        122367 non-null  int64
# dtypes: int64(3), object(8)
# memory usage: 10.3+ MB

# %% [markdown]
# Check
# * Space: ``df["First Name"].str.contains("TERENCIO")``
# * Hyphen: ``df["First Name"] == "KHOMEINY"``
# * Period: ``df["Last Name"] == "LACUNA"``
# etc.

# %%
df["Region"] = df["Region"].replace({"REGION IV-B" : "MIMAROPA"})
df["Province"] = df["Province"].replace({"DAVAO DE ORO" : "COMPOSTELA VALLEY"})
for col in ["First Name", "Middle Name", "Last Name"]:
    df[col] = df[col] \
        .str.strip() \
        .str.replace("-", " ") \
        .str.replace(".", "") \
        .str.replace("Ã‘", "N").str.replace("Ñ", "N") \
        .str.replace(r"[;`,]", "", regex = True)

# %%
df_politicians = df[["First Name", "Middle Name", "Last Name"]].copy()
df_politicians = df_politicians.drop_duplicates()

# %%
df_politicians.to_csv("datasets/politicians.csv", index = False)

# %%
df.to_csv("datasets/political_dynasty_v9.csv", index = False)

# %% [markdown]
# Region-Province Mapping

# %%
region_dict = {
    1 : "REGION I", # "ILOCOS REGION",
    2 : "REGION II", # "CAGAYAN VALLEY",
    3 : "REGION III", # "CENTRAL LUZON",
    4 : "REGION IV-A", # "CALABARZON",
    5 : "REGION V", # "BICOL REGION",
    6 : "REGION VI", # "WESTERN VISAYAS",
    7 : "REGION VII", # "CENTRAL VISAYAS",
    8 : "REGION VIII", # "EASTERN VISAYAS",
    9 : "REGION IX", # "ZAMBOANGA PENINSULA",
    10 : "REGION X", # "NORTHEN MINDANAO",
    11 : "REGION XI", # "DAVAO REGION",
    12 : "REGION XII", # "SOCCSKSARGEN",
    13 : "NATIONAL CAPITAL REGION",
    14 : "CORDILLERA ADMINISTRATIVE REGION",
    16 : "REGION XIII", # CARAGA
    17 : "MIMAROPA",
    19 : "AUTONOMOUS REGION IN MUSLIM MINDANAO"
}

df_ref = pd.read_csv("datasets/PH_Adm2_ProvDists.csv")
df_ref = df_ref[["adm1_psgc", "adm2_en"]].dropna()
df_ref.columns = ["Region", "Province"]

df_ref["Province"] = df_ref["Province"].str.upper()
df_ref["Region"] = df_ref["Region"] / 100000000
df_ref["Region"] = df_ref["Region"].astype(int)
df_ref["Region"] = df_ref["Region"].map(region_dict)
df_ref["Province"] = df_ref["Province"].str.replace(" (NOT A PROVINCE)", "")

df_ref["Province"] = df_ref["Province"].replace(
    {"DAVAO DE ORO" : "COMPOSTELA VALLEY",
     "MAGUINDANAO DEL NORTE" : "MAGUINDANAO"}
)
df_ref = df_ref[df_ref["Province"] != "MAGUINDANAO DEL SUR"]
df_ref
# Out:
#                                   Region       Province
# 0                               REGION I   ILOCOS NORTE
# 1                               REGION I     ILOCOS SUR
# 2                               REGION I       LA UNION
# 3                               REGION I     PANGASINAN
# 4                              REGION II        BATANES
# ..                                   ...            ...
# 81  AUTONOMOUS REGION IN MUSLIM MINDANAO        BASILAN
# 82  AUTONOMOUS REGION IN MUSLIM MINDANAO  LANAO DEL SUR
# 83  AUTONOMOUS REGION IN MUSLIM MINDANAO           SULU
# 84  AUTONOMOUS REGION IN MUSLIM MINDANAO      TAWI-TAWI
# 85  AUTONOMOUS REGION IN MUSLIM MINDANAO    MAGUINDANAO
#
# [86 rows x 2 columns]

# %%
# df_ref.to_csv("datasets/region_province.csv", index = False)

# %% [markdown]
# Extras

# %%
region_province_pairs = set(zip(df_ref["Region"], df_ref["Province"]))
mask = df.apply(lambda row: (row["Region"], row["Province"]) in region_province_pairs, axis = 1)
df["mask"] = mask + 0
df["mask"].value_counts()
# Out:
# mask
# 1    103786
# 0     18581
# Name: count, dtype: int64

# %%
# for updating (null Region)
df[(df["mask"] == 0) & (df["Region"].isna())]
# Out:
#           Last Name  First Name Middle Name                          Position  \
# 86606       SINSUAT        DATU       BIMBO  MEMBER, HOUSE OF REPRESENTATIVES
# 86607       SINSUAT        DATU       BIMBO  MEMBER, HOUSE OF REPRESENTATIVES
# 86608   MANGUDADATU      ESMAEL      GAGUIL  MEMBER, HOUSE OF REPRESENTATIVES
# 86609           TAN      SAMIER    ABUBAKAR  MEMBER, HOUSE OF REPRESENTATIVES
# 86610       ARBISON       MUNIR         NaN  MEMBER, HOUSE OF REPRESENTATIVES
# ...             ...         ...         ...                               ...
# 104735      JENKINS       MARIA         NaN           PROVINCIAL BOARD MEMBER
# 104736       ALZATE      BYRONE   BELISARIO           PROVINCIAL BOARD MEMBER
# 104737        ABAYA  PATROCINIO    BERSAMIN           PROVINCIAL BOARD MEMBER
# 104738        ANGAS      PRINCE         NaN           PROVINCIAL BOARD MEMBER
# 104739          TAN   ABDUSAKUR      MAHAIL                          GOVERNOR
#
#          Party  Year       Province Region  Position Weight  \
# 86606   PDPLBN  2019  LANAO DEL SUR    NaN                5
# 86607   PDPLBN  2019  LANAO DEL SUR    NaN                5
# 86608   PDPLBN  2019        BASILAN    NaN                5
# 86609   NPTAWI  2019        BASILAN    NaN                5
# 86610   PDPLBN  2019  LANAO DEL SUR    NaN                5
# ...        ...   ...            ...    ...              ...
# 104735  ASENSO  2019           ABRA    NaN                2
# 104736  ASENSO  2019           ABRA    NaN                2
# 104737  ASENSO  2019           ABRA    NaN                2
# 104738  PDPLBN  2019    MAGUINDANAO    NaN                2
# 104739  PDPLBN  2019           SULU    NaN                5
#
#                         Full Name  Community  mask
# 86606          DATU BIMBO SINSUAT        190     0
# 86607          DATU BIMBO SINSUAT        190     0
# 86608   ESMAEL GAGUIL MANGUDADATU         86     0
# 86609         SAMIER ABUBAKAR TAN          0     0
# 86610              MUNIR  ARBISON        191     0
# ...                           ...        ...   ...
# 104735             MARIA  JENKINS        383     0
# 104736    BYRONE BELISARIO ALZATE          3     0
# 104737  PATROCINIO BERSAMIN ABAYA          4     0
# 104738              PRINCE  ANGAS          6     0
# 104739       ABDUSAKUR MAHAIL TAN          1     0
#
# [18134 rows x 12 columns]

# %%
# for deleting
df[(df["mask"] == 0) & (df["Region"].notna())]
# Out:
#        Last Name First Name Middle Name                 Position      Party  \
# 246      CUNANAN    CECILIA       NUNAG                COUNCILOR        NPC
# 302         CRUZ      JESUS        CRUZ  PROVINCIAL BOARD MEMBER        PMP
# 396     BANTILAN       JOEL       JUBAY                COUNCILOR  LAKAS-CMD
# 451        PANAL  CHARLOTTE    DUMANJUG                COUNCILOR  LAKAS-CMD
# 508         CRUZ      JESUS        CRUZ               VICE MAYOR  LAKAS-CMD
# ...          ...        ...         ...                      ...        ...
# 121566     DIZON      ROMEO    CAYETANO                COUNCILOR     PDPLBN
# 121712       LIM      ALLAN      JAGMAN  PROVINCIAL BOARD MEMBER     PDPLBN
# 121713       LIM      ALLAN      JAGMAN  PROVINCIAL BOARD MEMBER     PDPLBN
# 121731       LIM      ALLAN      JAGMAN  PROVINCIAL BOARD MEMBER     PDPLBN
# 121732       LIM      ALLAN      JAGMAN  PROVINCIAL BOARD MEMBER     PDPLBN
#
#         Year           Province                   Region  Position Weight  \
# 246     2004            PALAWAN               REGION III                2
# 302     2004           PAMPANGA                REGION II                2
# 396     2004     AGUSAN DEL SUR                 REGION X                2
# 451     2004  ZAMBOANGA DEL SUR                 REGION X                2
# 508     2004           PAMPANGA  NATIONAL CAPITAL REGION                3
# ...      ...                ...                      ...              ...
# 121566  2022            BULACAN              REGION XIII                2
# 121712  2022    LANAO DEL NORTE              REGION XIII                2
# 121713  2022    LANAO DEL NORTE              REGION XIII                2
# 121731  2022    LANAO DEL NORTE              REGION XIII                2
# 121732  2022    LANAO DEL NORTE              REGION XIII                2
#
#                        Full Name  Community  mask
# 246        CECILIA NUNAG CUNANAN        195     0
# 302              JESUS CRUZ CRUZ          2     0
# 396          JOEL JUBAY BANTILAN        123     0
# 451     CHARLOTTE DUMANJUG PANAL        245     0
# 508              JESUS CRUZ CRUZ          2     0
# ...                          ...        ...   ...
# 121566      ROMEO CAYETANO DIZON        172     0
# 121712          ALLAN JAGMAN LIM          1     0
# 121713          ALLAN JAGMAN LIM          1     0
# 121731          ALLAN JAGMAN LIM          1     0
# 121732          ALLAN JAGMAN LIM          1     0
#
# [447 rows x 12 columns]

# %%
misclassified = pd.DataFrame(df[~mask][["Region", "Province"]].value_counts().sort_index())
for region, provinces in misclassified.groupby(level = 0):
    print(region, ":", list(provinces.index.get_level_values(1)))
# Out:
# AUTONOMOUS REGION IN MUSLIM MINDANAO : ['PALAWAN']
# CORDILLERA ADMINISTRATIVE REGION : ['CAMARINES SUR', 'COTABATO', 'ILOCOS NORTE', 'LA UNION', 'TARLAC']
# MIMAROPA : ['ISABELA', 'PANGASINAN', 'SARANGANI']
# NATIONAL CAPITAL REGION : ['BATAAN', 'ISABELA', 'LAGUNA', 'NUEVA ECIJA', 'PAMPANGA', 'QUEZON']
# REGION I : ['ABRA', 'AGUSAN DEL SUR', 'AKLAN', 'AURORA', 'BATANGAS', 'BULACAN', 'CAGAYAN', 'GUIMARAS', 'ISABELA', 'LANAO DEL NORTE', 'PAMPANGA', 'QUIRINO', 'SOUTHERN LEYTE']
# REGION II : ['ALBAY', 'BATANGAS', 'DAVAO ORIENTAL', 'IFUGAO', 'LANAO DEL NORTE', 'NEGROS OCCIDENTAL', 'PAMPANGA', 'PANGASINAN', 'QUEZON', 'RIZAL', 'ZAMBALES', 'ZAMBOANGA DEL NORTE']
# REGION III : ['ABRA', 'AKLAN', 'BATANGAS', 'BOHOL', 'CAMARINES SUR', 'CAVITE', 'COTABATO', 'DINAGAT ISLANDS', 'ILOCOS SUR', 'LAGUNA', 'NCR, CITY OF MANILA, FIRST DISTRICT', 'NCR, FOURTH DISTRICT', 'NCR, SECOND DISTRICT', 'NEGROS OCCIDENTAL', 'PALAWAN', 'PANGASINAN', 'ROMBLON', 'SAMAR', 'SOUTHERN LEYTE', 'SULTAN KUDARAT', 'SURIGAO DEL SUR']
# REGION IV-A : ['ABRA', 'BULACAN', 'ILOCOS NORTE', 'ISABELA', 'NCR, FOURTH DISTRICT', 'NUEVA ECIJA', 'NUEVA VIZCAYA', 'OCCIDENTAL MINDORO', 'ORIENTAL MINDORO', 'PALAWAN', 'QUIRINO', 'ROMBLON', 'ZAMBOANGA DEL SUR']
# REGION IX : ['BASILAN', 'ILOCOS SUR', 'ISABELA', 'LA UNION', 'NUEVA ECIJA', 'PAMPANGA', 'SAMAR']
# REGION V : ['AKLAN', 'AURORA', 'BOHOL', 'CAGAYAN', 'CEBU', 'ILOCOS SUR', 'LANAO DEL NORTE', 'NCR, FOURTH DISTRICT', 'NEGROS OCCIDENTAL', 'PANGASINAN', 'SAMAR', 'SOUTHERN LEYTE']
# REGION VI : ['CAMARINES SUR', 'LANAO DEL NORTE', 'NEGROS ORIENTAL', 'PALAWAN', 'PAMPANGA', 'PANGASINAN', 'RIZAL']
# REGION VII : ['BATANGAS', 'DAVAO DEL NORTE', 'ILOCOS SUR', 'NCR, FOURTH DISTRICT', 'NORTHERN SAMAR', 'SAMAR', 'SULTAN KUDARAT', 'ZAMBOANGA SIBUGAY']
# REGION VIII : ['AKLAN', 'ANTIQUE', 'BATANGAS', 'BOHOL', 'CAMARINES NORTE', 'CAVITE', 'DAVAO ORIENTAL', 'ILOCOS SUR', 'MISAMIS ORIENTAL', 'NCR, FOURTH DISTRICT', 'ZAMBOANGA DEL NORTE']
# REGION X : ['ABRA', 'AGUSAN DEL SUR', 'CAGAYAN', 'DAVAO DEL NORTE', 'ILOCOS SUR', 'LA UNION', 'QUEZON', 'ZAMBOANGA DEL SUR']
# REGION XI : ['NEGROS OCCIDENTAL', 'PALAWAN', 'QUEZON']
# REGION XII : ['DAVAO DEL SUR', 'NCR, FOURTH DISTRICT', 'NUEVA ECIJA', 'SURIGAO DEL SUR', 'TARLAC', 'ZAMBOANGA DEL NORTE', 'ZAMBOANGA DEL SUR']
# REGION XIII : ['BOHOL', 'BULACAN', 'ILOCOS NORTE', 'LANAO DEL NORTE', 'NORTHERN SAMAR', 'PAMPANGA', 'PANGASINAN', 'ZAMBOANGA DEL SUR']

# %% [markdown]
# # Graph

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.animation as animation
import networkx as nx
from pyvis.network import Network

# %%
province = "ILOCOS NORTE"
year = 2004

# %%
data = pd.read_csv("datasets/Political Dynasty v9.csv")
data
# Out:
#        Last Name  First Name  Middle Name   Position      Party  Year  \
# 0         ACOSTA  CHERRY PIE  BALLESTEROS  COUNCILOR         LP  2004
# 1          OLVIS    ANACLETO        HAMOY      MAYOR       PDSP  2004
# 2       LACAMBRA       PRIMO        PABLO  COUNCILOR        NPC  2004
# 3       HALLAZGO     EMEDIOS       MARBAN  COUNCILOR  LAKAS-CMD  2004
# 4         LABUNI       EDGAR         TELA  COUNCILOR        NPC  2004
# ...          ...         ...          ...        ...        ...   ...
# 122362  BAUTISTA      EVELYN     SOMBILLA  COUNCILOR      LAKAS  2022
# 122363  ESPINOZA     MARIBEL     REALISTA  COUNCILOR        IND  2022
# 122364  CAHATIAN       JOPIE     LINGGAYA  COUNCILOR      LAKAS  2022
# 122365    DELOSO       MOMAR        ACDOG  COUNCILOR     HUGPNG  2022
# 122366  CALLUENG     CONRADO      RUMUSUD  COUNCILOR     PDPLBN  2022
#
#                    Province       Region  Position Weight  \
# 0                   PALAWAN  REGION IV-B                2
# 1       ZAMBOANGA DEL NORTE    REGION IX                5
# 2                PANGASINAN     REGION I                2
# 3          MISAMIS ORIENTAL     REGION X                2
# 4                   CAGAYAN    REGION II                2
# ...                     ...          ...              ...
# 122362      SURIGAO DEL SUR  REGION XIII                2
# 122363      SURIGAO DEL SUR  REGION XIII                2
# 122364      SURIGAO DEL SUR  REGION XIII                2
# 122365      SURIGAO DEL SUR  REGION XIII                2
# 122366              CAGAYAN    REGION II                2
#
#                             Full Name  Community
# 0       CHERRY PIE BALLESTEROS ACOSTA         10
# 1                ANACLETO HAMOY OLVIS          0
# 2                PRIMO PABLO LACAMBRA         63
# 3             EMEDIOS MARBAN HALLAZGO         15
# 4                   EDGAR TELA LABUNI        213
# ...                               ...        ...
# 122362       EVELYN SOMBILLA BAUTISTA        207
# 122363      MARIBEL REALISTA ESPINOZA         15
# 122364        JOPIE LINGGAYA CAHATIAN        208
# 122365             MOMAR ACDOG DELOSO         26
# 122366       CONRADO RUMUSUD CALLUENG          0
#
# [122367 rows x 11 columns]

# %%
# Filter and sort data for the given province and year
df_province_year = data[(data["Province"] == province) & (data["Year"] == year)].sort_values(by = ["Year"], ascending = False)

# Drop duplicates
df_unique_names = df_province_year.drop_duplicates(subset = ["Full Name"], keep = "first").copy()
df_unique_names = df_unique_names.fillna("")

# Pre-compute values for faster lookup
name_data = df_unique_names.set_index("Full Name")[["Last Name", "Middle Name", "Position Weight", "Community", "Position"]].to_dict(orient = "index")

# Use NumPy for faster matrix operations
names = df_unique_names["Full Name"].unique()
num_names = len(names)
am = np.zeros((num_names, num_names), dtype = int)

# %%
df_province_year
# Out:
#        Last Name First Name Middle Name   Position      Party  Year  \
# 191     BANGAOAN     LIBRES         NaN  COUNCILOR  LAKAS-CMD  2004
# 10103     EDROZO     ALIPIO         NaN  COUNCILOR  LAKAS-CMD  2004
# 10323    SANCHEZ     DENNIS     JAMBARO  COUNCILOR  LAKAS-CMD  2004
# 10357      SACPA      DANNY      TUGADE  COUNCILOR  LAKAS-CMD  2004
# 10364      SACRO        BOB     GOROSPE  COUNCILOR  LAKAS-CMD  2004
# ...          ...        ...         ...        ...        ...   ...
# 5925       RAMOS  PRIMO JAY         NaN  COUNCILOR        NPC  2004
# 5977      TUKIAD       JUAN         NaN  COUNCILOR        NPC  2004
# 6024   ZAFARALLA    QUIRICO    GUERRERO  COUNCILOR        IND  2004
# 6068   ERMITANIO   RODERICK         NaN  COUNCILOR        KBL  2004
# 17376    DOMINGO    ARACELI       DAVID  COUNCILOR        LDP  2004
#
#            Province    Region  Position Weight                   Full Name  \
# 191    ILOCOS NORTE  REGION I                2            LIBRES  BANGAOAN
# 10103  ILOCOS NORTE  REGION I                2              ALIPIO  EDROZO
# 10323  ILOCOS NORTE  REGION I                2      DENNIS JAMBARO SANCHEZ
# 10357  ILOCOS NORTE  REGION I                2          DANNY TUGADE SACPA
# 10364  ILOCOS NORTE  REGION I                2           BOB GOROSPE SACRO
# ...             ...       ...              ...                         ...
# 5925   ILOCOS NORTE  REGION I                2            PRIMO JAY  RAMOS
# 5977   ILOCOS NORTE  REGION I                2                JUAN  TUKIAD
# 6024   ILOCOS NORTE  REGION I                2  QUIRICO GUERRERO ZAFARALLA
# 6068   ILOCOS NORTE  REGION I                2         RODERICK  ERMITANIO
# 17376  ILOCOS NORTE  REGION I                2       ARACELI DAVID DOMINGO
#
#        Community
# 191          144
# 10103         28
# 10323        208
# 10357        209
# 10364        210
# ...          ...
# 5925         177
# 5977         178
# 6024         179
# 6068         180
# 17376         10
#
# [247 rows x 11 columns]

# %%
name_data
# Out:
# {'LIBRES  BANGAOAN': {'Last Name': 'BANGAOAN',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 144,
#   'Position': 'COUNCILOR'},
#  'ALIPIO  EDROZO': {'Last Name': 'EDROZO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 28,
#   'Position': 'COUNCILOR'},
#  'DENNIS JAMBARO SANCHEZ': {'Last Name': 'SANCHEZ',
#   'Middle Name': 'JAMBARO',
#   'Position Weight': 2,
#   'Community': 208,
#   'Position': 'COUNCILOR'},
#  'DANNY TUGADE SACPA': {'Last Name': 'SACPA',
#   'Middle Name': 'TUGADE',
#   'Position Weight': 2,
#   'Community': 209,
#   'Position': 'COUNCILOR'},
#  'BOB GOROSPE SACRO': {'Last Name': 'SACRO',
#   'Middle Name': 'GOROSPE',
#   'Position Weight': 2,
#   'Community': 210,
#   'Position': 'COUNCILOR'},
#  'WAGNER AGAMAS POKING': {'Last Name': 'POKING',
#   'Middle Name': 'AGAMAS',
#   'Position Weight': 3,
#   'Community': 211,
#   'Position': 'VICE MAYOR'},
#  'CRISANTO MOLINA SAMBRANO': {'Last Name': 'SAMBRANO',
#   'Middle Name': 'MOLINA',
#   'Position Weight': 2,
#   'Community': 212,
#   'Position': 'COUNCILOR'},
#  'RODOLFO RAMON SALNO': {'Last Name': 'SALNO',
#   'Middle Name': 'RAMON',
#   'Position Weight': 2,
#   'Community': 213,
#   'Position': 'COUNCILOR'},
#  'RENATO  SALUDARES': {'Last Name': 'SALUDARES',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 214,
#   'Position': 'COUNCILOR'},
#  'TEODORO DALLUYON DUPAGEN': {'Last Name': 'DUPAGEN',
#   'Middle Name': 'DALLUYON',
#   'Position Weight': 2,
#   'Community': 30,
#   'Position': 'COUNCILOR'},
#  'WILMA BURAWI DUPAGEN': {'Last Name': 'DUPAGEN',
#   'Middle Name': 'BURAWI',
#   'Position Weight': 5,
#   'Community': 30,
#   'Position': 'MAYOR'},
#  'ROBERT  SADUMIANO': {'Last Name': 'SADUMIANO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 215,
#   'Position': 'COUNCILOR'},
#  'MILAGROS  DY': {'Last Name': 'DY',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 216,
#   'Position': 'COUNCILOR'},
#  'AUGUSTUS ANCHETA SALAZAR': {'Last Name': 'SALAZAR',
#   'Middle Name': 'ANCHETA',
#   'Position Weight': 5,
#   'Community': 217,
#   'Position': 'MAYOR'},
#  'MELCHOR MADAMBA ACIO': {'Last Name': 'ACIO',
#   'Middle Name': 'MADAMBA',
#   'Position Weight': 2,
#   'Community': 218,
#   'Position': 'COUNCILOR'},
#  'FRANKLIN  ACEBEDO': {'Last Name': 'ACEBEDO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 219,
#   'Position': 'COUNCILOR'},
#  'RENATO MA.  PERALTA': {'Last Name': 'PERALTA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 31,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'DOMINADOR PABLO LIGOT': {'Last Name': 'LIGOT',
#   'Middle Name': 'PABLO',
#   'Position Weight': 2,
#   'Community': 32,
#   'Position': 'COUNCILOR'},
#  'CHRISTIAN RAFAEL ALI PERALTA': {'Last Name': 'PERALTA',
#   'Middle Name': 'ALI',
#   'Position Weight': 2,
#   'Community': 31,
#   'Position': 'COUNCILOR'},
#  'EDWIN BAGALARO ABROJENA': {'Last Name': 'ABROJENA',
#   'Middle Name': 'BAGALARO',
#   'Position Weight': 2,
#   'Community': 220,
#   'Position': 'COUNCILOR'},
#  'CESAR GONZALES LLAGUNO': {'Last Name': 'LLAGUNO',
#   'Middle Name': 'GONZALES',
#   'Position Weight': 2,
#   'Community': 4,
#   'Position': 'COUNCILOR'},
#  'JORGE DAGUIO ACUPIDO': {'Last Name': 'ACUPIDO',
#   'Middle Name': 'DAGUIO',
#   'Position Weight': 2,
#   'Community': 2,
#   'Position': 'COUNCILOR'},
#  'ODON MAGARRO AGUINALDO': {'Last Name': 'AGUINALDO',
#   'Middle Name': 'MAGARRO',
#   'Position Weight': 3,
#   'Community': 1,
#   'Position': 'VICE MAYOR'},
#  'NESTOR REY RUIZ AGUINALDO': {'Last Name': 'AGUINALDO',
#   'Middle Name': 'RUIZ',
#   'Position Weight': 2,
#   'Community': 1,
#   'Position': 'COUNCILOR'},
#  'FELIX DANCEL AGUINALDO': {'Last Name': 'AGUINALDO',
#   'Middle Name': 'DANCEL',
#   'Position Weight': 2,
#   'Community': 1,
#   'Position': 'COUNCILOR'},
#  'ISMAEL LUZ AGULAY': {'Last Name': 'AGULAY',
#   'Middle Name': 'LUZ',
#   'Position Weight': 2,
#   'Community': 6,
#   'Position': 'COUNCILOR'},
#  'OSCAR DANCEL AGUINALDO': {'Last Name': 'AGUINALDO',
#   'Middle Name': 'DANCEL',
#   'Position Weight': 5,
#   'Community': 1,
#   'Position': 'MAYOR'},
#  'BIENVENIDO AGLUGUB ALABANZA': {'Last Name': 'ALABANZA',
#   'Middle Name': 'AGLUGUB',
#   'Position Weight': 2,
#   'Community': 221,
#   'Position': 'COUNCILOR'},
#  'MACARTHUR ACOSTA AGUINALDO': {'Last Name': 'AGUINALDO',
#   'Middle Name': 'ACOSTA',
#   'Position Weight': 2,
#   'Community': 1,
#   'Position': 'COUNCILOR'},
#  'RONALD EUGENIO SANTIAGO': {'Last Name': 'SANTIAGO',
#   'Middle Name': 'EUGENIO',
#   'Position Weight': 2,
#   'Community': 29,
#   'Position': 'COUNCILOR'},
#  'WYRLO  EDROZO': {'Last Name': 'EDROZO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 28,
#   'Position': 'COUNCILOR'},
#  'BENIGNO  DE LA CRUZ': {'Last Name': 'DE LA CRUZ',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 16,
#   'Position': 'COUNCILOR'},
#  'JESSIE PASION PUMARAS': {'Last Name': 'PUMARAS',
#   'Middle Name': 'PASION',
#   'Position Weight': 2,
#   'Community': 207,
#   'Position': 'COUNCILOR'},
#  'RUBEN  VENTURA': {'Last Name': 'VENTURA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 198,
#   'Position': 'COUNCILOR'},
#  'MAGNO ANTONIO GONZALES FORONDA': {'Last Name': 'FORONDA',
#   'Middle Name': 'GONZALES',
#   'Position Weight': 2,
#   'Community': 4,
#   'Position': 'COUNCILOR'},
#  'QUIRINO  RAVAL': {'Last Name': 'RAVAL',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 6,
#   'Position': 'COUNCILOR'},
#  'CONSTANCIO TAMAYO TAMAYO': {'Last Name': 'TAMAYO',
#   'Middle Name': 'TAMAYO',
#   'Position Weight': 2,
#   'Community': 13,
#   'Position': 'COUNCILOR'},
#  'ALICIA SALADINO TAMAYO': {'Last Name': 'TAMAYO',
#   'Middle Name': 'SALADINO',
#   'Position Weight': 2,
#   'Community': 13,
#   'Position': 'COUNCILOR'},
#  'ALEXANDER  VALERA': {'Last Name': 'VALERA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 199,
#   'Position': 'COUNCILOR'},
#  'MARIANITO PIEDAD FORONDA': {'Last Name': 'FORONDA',
#   'Middle Name': 'PIEDAD',
#   'Position Weight': 2,
#   'Community': 4,
#   'Position': 'COUNCILOR'},
#  'JOSE GAMIAO FORONDA': {'Last Name': 'FORONDA',
#   'Middle Name': 'GAMIAO',
#   'Position Weight': 3,
#   'Community': 4,
#   'Position': 'VICE MAYOR'},
#  'ERDIO ESPEJO VALENZUELA': {'Last Name': 'VALENZUELA',
#   'Middle Name': 'ESPEJO',
#   'Position Weight': 2,
#   'Community': 200,
#   'Position': 'COUNCILOR'},
#  'CARDITO MANIBOG TAMAYO': {'Last Name': 'TAMAYO',
#   'Middle Name': 'MANIBOG',
#   'Position Weight': 2,
#   'Community': 13,
#   'Position': 'COUNCILOR'},
#  'MARLON WAYNE  MANUEL': {'Last Name': 'MANUEL',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 5,
#   'Position': 'COUNCILOR'},
#  'MARCELO  MANUEL': {'Last Name': 'MANUEL',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 5,
#   'Position': 'COUNCILOR'},
#  'DOMINGO CURIMAO AMBROCIO': {'Last Name': 'AMBROCIO',
#   'Middle Name': 'CURIMAO',
#   'Position Weight': 2,
#   'Community': 201,
#   'Position': 'COUNCILOR'},
#  'ROMEO AGPAOA GUIRA': {'Last Name': 'GUIRA',
#   'Middle Name': 'AGPAOA',
#   'Position Weight': 2,
#   'Community': 202,
#   'Position': 'COUNCILOR'},
#  'MARCELO PASCUA ANDAYA': {'Last Name': 'ANDAYA',
#   'Middle Name': 'PASCUA',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'JOSEPH ESPIRITU DE LARA': {'Last Name': 'DE LARA',
#   'Middle Name': 'ESPIRITU',
#   'Position Weight': 5,
#   'Community': 6,
#   'Position': 'MAYOR'},
#  'EDISON ESPIRITU DE LARA': {'Last Name': 'DE LARA',
#   'Middle Name': 'ESPIRITU',
#   'Position Weight': 3,
#   'Community': 6,
#   'Position': 'VICE MAYOR'},
#  'JONATHAN LUZ DE LARA': {'Last Name': 'DE LARA',
#   'Middle Name': 'LUZ',
#   'Position Weight': 2,
#   'Community': 6,
#   'Position': 'COUNCILOR'},
#  'AMEURFINA  SALENDA': {'Last Name': 'SALENDA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 203,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'ELEUTERIO CHUA MABANAG': {'Last Name': 'MABANAG',
#   'Middle Name': 'CHUA',
#   'Position Weight': 5,
#   'Community': 2,
#   'Position': 'MAYOR'},
#  'GEORGE AGUINALDO SAMALIO': {'Last Name': 'SAMALIO',
#   'Middle Name': 'AGUINALDO',
#   'Position Weight': 2,
#   'Community': 1,
#   'Position': 'COUNCILOR'},
#  'MARLON FERDINAND TORRES SALES': {'Last Name': 'SALES',
#   'Middle Name': 'TORRES',
#   'Position Weight': 5,
#   'Community': 17,
#   'Position': 'MAYOR'},
#  'GENEROSO LEON AQUINO': {'Last Name': 'AQUINO',
#   'Middle Name': 'LEON',
#   'Position Weight': 2,
#   'Community': 204,
#   'Position': 'COUNCILOR'},
#  'ALMOND  LEANO': {'Last Name': 'LEANO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 205,
#   'Position': 'COUNCILOR'},
#  'MARIO MADOLORA LAZO': {'Last Name': 'LAZO',
#   'Middle Name': 'MADOLORA',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'VICENTITO MANDAC LAZO': {'Last Name': 'LAZO',
#   'Middle Name': 'MANDAC',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'ROBERT  ALMAZAN': {'Last Name': 'ALMAZAN',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 206,
#   'Position': 'COUNCILOR'},
#  'MELCHOR BATARA GUILLEN': {'Last Name': 'GUILLEN',
#   'Middle Name': 'BATARA',
#   'Position Weight': 2,
#   'Community': 222,
#   'Position': 'COUNCILOR'},
#  'ELSIE  DE LA CRUZ': {'Last Name': 'DE LA CRUZ',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 16,
#   'Position': 'COUNCILOR'},
#  'GERVACIO  VICENTE': {'Last Name': 'VICENTE',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 196,
#   'Position': 'COUNCILOR'},
#  'ROQUE  ABLAN': {'Last Name': 'ABLAN',
#   'Middle Name': '',
#   'Position Weight': 5,
#   'Community': 239,
#   'Position': 'MEMBER, HOUSE OF REPRESENTATIVES'},
#  'CAMILO  RONDAL': {'Last Name': 'RONDAL',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 241,
#   'Position': 'COUNCILOR'},
#  'CORAZON RUIZ ABAD': {'Last Name': 'ABAD',
#   'Middle Name': 'RUIZ',
#   'Position Weight': 5,
#   'Community': 1,
#   'Position': 'MAYOR'},
#  'JUAN CONRADO ABSING RESPICIO': {'Last Name': 'RESPICIO',
#   'Middle Name': 'ABSING',
#   'Position Weight': 2,
#   'Community': 242,
#   'Position': 'COUNCILOR'},
#  'ELISEO  RESURRECCION': {'Last Name': 'RESURRECCION',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 243,
#   'Position': 'COUNCILOR'},
#  'ROLY REX IGNACIO SANTIAGO': {'Last Name': 'SANTIAGO',
#   'Middle Name': 'IGNACIO',
#   'Position Weight': 2,
#   'Community': 29,
#   'Position': 'COUNCILOR'},
#  'ROSARIO CHUA GO': {'Last Name': 'GO',
#   'Middle Name': 'CHUA',
#   'Position Weight': 5,
#   'Community': 2,
#   'Position': 'MAYOR'},
#  'GABRIEL DUMLAO REYES': {'Last Name': 'REYES',
#   'Middle Name': 'DUMLAO',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'NESTOR DALISAY REYES': {'Last Name': 'REYES',
#   'Middle Name': 'DALISAY',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'CARLITO AGUILAR ABADILLA': {'Last Name': 'ABADILLA',
#   'Middle Name': 'AGUILAR',
#   'Position Weight': 5,
#   'Community': 5,
#   'Position': 'MAYOR'},
#  'CLEMENTE PIGOTI ABAL': {'Last Name': 'ABAL',
#   'Middle Name': 'PIGOTI',
#   'Position Weight': 2,
#   'Community': 244,
#   'Position': 'COUNCILOR'},
#  'JIMMY ONG CHUA': {'Last Name': 'CHUA',
#   'Middle Name': 'ONG',
#   'Position Weight': 3,
#   'Community': 2,
#   'Position': 'VICE MAYOR'},
#  'ALBERT DAGUIO CHUA': {'Last Name': 'CHUA',
#   'Middle Name': 'DAGUIO',
#   'Position Weight': 3,
#   'Community': 2,
#   'Position': 'VICE MAYOR'},
#  'PURISIMA  BUENO': {'Last Name': 'BUENO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 245,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'WINDELL DAGUIO CHUA': {'Last Name': 'CHUA',
#   'Middle Name': 'DAGUIO',
#   'Position Weight': 3,
#   'Community': 2,
#   'Position': 'VICE GOVERNOR'},
#  'ANUNCIACION DULDULAO PAGDILAO': {'Last Name': 'PAGDILAO',
#   'Middle Name': 'DULDULAO',
#   'Position Weight': 5,
#   'Community': 246,
#   'Position': 'MAYOR'},
#  'SALVACION SALES CIMATU': {'Last Name': 'CIMATU',
#   'Middle Name': 'SALES',
#   'Position Weight': 3,
#   'Community': 17,
#   'Position': 'VICE MAYOR'},
#  'EFREN BELTRAN CIMATU': {'Last Name': 'CIMATU',
#   'Middle Name': 'BELTRAN',
#   'Position Weight': 2,
#   'Community': 17,
#   'Position': 'COUNCILOR'},
#  'JULIO AGDEPPA CABACUNGAN': {'Last Name': 'CABACUNGAN',
#   'Middle Name': 'AGDEPPA',
#   'Position Weight': 3,
#   'Community': 247,
#   'Position': 'VICE MAYOR'},
#  'MODESTO UMAROG CLEMENTE': {'Last Name': 'CLEMENTE',
#   'Middle Name': 'UMAROG',
#   'Position Weight': 3,
#   'Community': 35,
#   'Position': 'VICE MAYOR'},
#  'BONIFACIO CARPIO CLEMENTE': {'Last Name': 'CLEMENTE',
#   'Middle Name': 'CARPIO',
#   'Position Weight': 5,
#   'Community': 35,
#   'Position': 'MAYOR'},
#  'PEDRO IBALIO CIRIACO': {'Last Name': 'CIRIACO',
#   'Middle Name': 'IBALIO',
#   'Position Weight': 2,
#   'Community': 248,
#   'Position': 'COUNCILOR'},
#  'JONEL MENOR ROSQUETA': {'Last Name': 'ROSQUETA',
#   'Middle Name': 'MENOR',
#   'Position Weight': 2,
#   'Community': 249,
#   'Position': 'COUNCILOR'},
#  'ALMA PALAFOX RUBIO': {'Last Name': 'RUBIO',
#   'Middle Name': 'PALAFOX',
#   'Position Weight': 2,
#   'Community': 250,
#   'Position': 'COUNCILOR'},
#  'GALEN UMAYAM POBRE': {'Last Name': 'POBRE',
#   'Middle Name': 'UMAYAM',
#   'Position Weight': 2,
#   'Community': 251,
#   'Position': 'COUNCILOR'},
#  'REYNALDO  DUMLAO': {'Last Name': 'DUMLAO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'JULIET  RUIZ': {'Last Name': 'RUIZ',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 1,
#   'Position': 'COUNCILOR'},
#  'SALVADOR SULQUIANO PILLOS': {'Last Name': 'PILLOS',
#   'Middle Name': 'SULQUIANO',
#   'Position Weight': 3,
#   'Community': 240,
#   'Position': 'VICE MAYOR'},
#  'ROMUALDO ABADILLA CASCAYAN': {'Last Name': 'CASCAYAN',
#   'Middle Name': 'ABADILLA',
#   'Position Weight': 2,
#   'Community': 5,
#   'Position': 'COUNCILOR'},
#  'NICOMEDES  DE LA CRUZ': {'Last Name': 'DE LA CRUZ',
#   'Middle Name': '',
#   'Position Weight': 3,
#   'Community': 16,
#   'Position': 'VICE MAYOR'},
#  'LARRY MANUEL CASCAYAN': {'Last Name': 'CASCAYAN',
#   'Middle Name': 'MANUEL',
#   'Position Weight': 2,
#   'Community': 5,
#   'Position': 'COUNCILOR'},
#  'MELVIN  DE LA CUESTA': {'Last Name': 'DE LA CUESTA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 223,
#   'Position': 'COUNCILOR'},
#  'ESTEBAN OBANDO AGOY': {'Last Name': 'AGOY',
#   'Middle Name': 'OBANDO',
#   'Position Weight': 3,
#   'Community': 224,
#   'Position': 'VICE MAYOR'},
#  'VIRGILIO LAGAZO AGOTO': {'Last Name': 'AGOTO',
#   'Middle Name': 'LAGAZO',
#   'Position Weight': 2,
#   'Community': 20,
#   'Position': 'COUNCILOR'},
#  'LILIA ALCARAZ AGBAYANI': {'Last Name': 'AGBAYANI',
#   'Middle Name': 'ALCARAZ',
#   'Position Weight': 2,
#   'Community': 33,
#   'Position': 'COUNCILOR'},
#  'CHARLES  AGBAYANI': {'Last Name': 'AGBAYANI',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 33,
#   'Position': 'COUNCILOR'},
#  'ISABELO ZALAMEDA AGLIPAY': {'Last Name': 'AGLIPAY',
#   'Middle Name': 'ZALAMEDA',
#   'Position Weight': 2,
#   'Community': 225,
#   'Position': 'COUNCILOR'},
#  'HENEDINA BALASI AFAGA': {'Last Name': 'AFAGA',
#   'Middle Name': 'BALASI',
#   'Position Weight': 2,
#   'Community': 226,
#   'Position': 'COUNCILOR'},
#  'NELSON CASTILLO OALOG': {'Last Name': 'OALOG',
#   'Middle Name': 'CASTILLO',
#   'Position Weight': 2,
#   'Community': 34,
#   'Position': 'COUNCILOR'},
#  'MARLON PASCUA PAHINAG': {'Last Name': 'PAHINAG',
#   'Middle Name': 'PASCUA',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'JOEGIE  JIMENEZ': {'Last Name': 'JIMENEZ',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 227,
#   'Position': 'COUNCILOR'},
#  'ED MAR VINCENT  BONOAN': {'Last Name': 'BONOAN',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 15,
#   'Position': 'COUNCILOR'},
#  'RUBEN  BLANCO': {'Last Name': 'BLANCO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 228,
#   'Position': 'COUNCILOR'},
#  'CORPUZ GATO BULIL-LIT': {'Last Name': 'BULIL-LIT',
#   'Middle Name': 'GATO',
#   'Position Weight': 2,
#   'Community': 229,
#   'Position': 'COUNCILOR'},
#  'SHERYL  PAGALING': {'Last Name': 'PAGALING',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 230,
#   'Position': 'COUNCILOR'},
#  'MENANDRO SIMON JULIAN': {'Last Name': 'JULIAN',
#   'Middle Name': 'SIMON',
#   'Position Weight': 2,
#   'Community': 231,
#   'Position': 'COUNCILOR'},
#  'JASON REGINALD ARZADON COLOMA': {'Last Name': 'COLOMA',
#   'Middle Name': 'ARZADON',
#   'Position Weight': 2,
#   'Community': 8,
#   'Position': 'COUNCILOR'},
#  'JOSE  CACAYORIN': {'Last Name': 'CACAYORIN',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 232,
#   'Position': 'COUNCILOR'},
#  'BERNARD DOLIKEN CABRADILLA': {'Last Name': 'CABRADILLA',
#   'Middle Name': 'DOLIKEN',
#   'Position Weight': 2,
#   'Community': 233,
#   'Position': 'COUNCILOR'},
#  'REIZEL ABROGENA CABIE': {'Last Name': 'CABIE',
#   'Middle Name': 'ABROGENA',
#   'Position Weight': 2,
#   'Community': 234,
#   'Position': 'COUNCILOR'},
#  'JOHN  CABARRUBIAS': {'Last Name': 'CABARRUBIAS',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 235,
#   'Position': 'COUNCILOR'},
#  'BENJAMIN  CAMPANANO': {'Last Name': 'CAMPANANO',
#   'Middle Name': '',
#   'Position Weight': 5,
#   'Community': 236,
#   'Position': 'MAYOR'},
#  'MANUEL BUTCH  CASTRO': {'Last Name': 'CASTRO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 9,
#   'Position': 'COUNCILOR'},
#  'ROBERTO PARADO CASTRO': {'Last Name': 'CASTRO',
#   'Middle Name': 'PARADO',
#   'Position Weight': 5,
#   'Community': 9,
#   'Position': 'MAYOR'},
#  'MITZI ANTONETTE MASAWAY CARTE': {'Last Name': 'CARTE',
#   'Middle Name': 'MASAWAY',
#   'Position Weight': 2,
#   'Community': 23,
#   'Position': 'COUNCILOR'},
#  'SAMY DENIS  OSTREA': {'Last Name': 'OSTREA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 237,
#   'Position': 'COUNCILOR'},
#  'LUCIANO RAGUTERO CARAANG': {'Last Name': 'CARAANG',
#   'Middle Name': 'RAGUTERO',
#   'Position Weight': 2,
#   'Community': 238,
#   'Position': 'COUNCILOR'},
#  'ANGELO BARBA ILAGA': {'Last Name': 'ILAGA',
#   'Middle Name': 'BARBA',
#   'Position Weight': 2,
#   'Community': 18,
#   'Position': 'COUNCILOR'},
#  'JIMMY DADIWA TARNATE': {'Last Name': 'TARNATE',
#   'Middle Name': 'DADIWA',
#   'Position Weight': 2,
#   'Community': 197,
#   'Position': 'COUNCILOR'},
#  'MELVIN AGULLANA VIERNES': {'Last Name': 'VIERNES',
#   'Middle Name': 'AGULLANA',
#   'Position Weight': 2,
#   'Community': 7,
#   'Position': 'COUNCILOR'},
#  'EUGENIO ANGELO SUR BARBA': {'Last Name': 'BARBA',
#   'Middle Name': 'SUR',
#   'Position Weight': 2,
#   'Community': 18,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'FRANCISCO RAVAL ESPIRITU': {'Last Name': 'ESPIRITU',
#   'Middle Name': 'RAVAL',
#   'Position Weight': 5,
#   'Community': 6,
#   'Position': 'MAYOR'},
#  'ROBERT BALBAG DALUSIAN': {'Last Name': 'DALUSIAN',
#   'Middle Name': 'BALBAG',
#   'Position Weight': 2,
#   'Community': 19,
#   'Position': 'COUNCILOR'},
#  'ALEJO MORALES LAGUITAN': {'Last Name': 'LAGUITAN',
#   'Middle Name': 'MORALES',
#   'Position Weight': 2,
#   'Community': 157,
#   'Position': 'COUNCILOR'},
#  'ZAMUEL FAHIGAL BALANTAC': {'Last Name': 'BALANTAC',
#   'Middle Name': 'FAHIGAL',
#   'Position Weight': 2,
#   'Community': 158,
#   'Position': 'COUNCILOR'},
#  'NORBERTO DOMINGO DADIZ': {'Last Name': 'DADIZ',
#   'Middle Name': 'DOMINGO',
#   'Position Weight': 3,
#   'Community': 10,
#   'Position': 'VICE MAYOR'},
#  'FERNANDO BAUTISTA BALAGSO': {'Last Name': 'BALAGSO',
#   'Middle Name': 'BAUTISTA',
#   'Position Weight': 2,
#   'Community': 159,
#   'Position': 'COUNCILOR'},
#  'JESUS DOLWE LAGAZO': {'Last Name': 'LAGAZO',
#   'Middle Name': 'DOLWE',
#   'Position Weight': 2,
#   'Community': 20,
#   'Position': 'COUNCILOR'},
#  'MAXIMO DAHILIG CAJIGAL': {'Last Name': 'CAJIGAL',
#   'Middle Name': 'DAHILIG',
#   'Position Weight': 2,
#   'Community': 2,
#   'Position': 'COUNCILOR'},
#  'MARY COLEEN C LUMANG CAJIGAL': {'Last Name': 'CAJIGAL',
#   'Middle Name': 'LUMANG',
#   'Position Weight': 2,
#   'Community': 2,
#   'Position': 'COUNCILOR'},
#  'GLENN GEORGE GO CAJIGAL': {'Last Name': 'CAJIGAL',
#   'Middle Name': 'GO',
#   'Position Weight': 3,
#   'Community': 2,
#   'Position': 'VICE MAYOR'},
#  'MELVYN BENEMERITO CALVAN': {'Last Name': 'CALVAN',
#   'Middle Name': 'BENEMERITO',
#   'Position Weight': 2,
#   'Community': 9,
#   'Position': 'COUNCILOR'},
#  'ATRINA PABLO ISLETA': {'Last Name': 'ISLETA',
#   'Middle Name': 'PABLO',
#   'Position Weight': 3,
#   'Community': 32,
#   'Position': 'VICE MAYOR'},
#  'LINDA  BADUA': {'Last Name': 'BADUA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 160,
#   'Position': 'COUNCILOR'},
#  'MELANIO JACOB PARADO': {'Last Name': 'PARADO',
#   'Middle Name': 'JACOB',
#   'Position Weight': 2,
#   'Community': 9,
#   'Position': 'COUNCILOR'},
#  'ELMER BRINGAS AZURIN': {'Last Name': 'AZURIN',
#   'Middle Name': 'BRINGAS',
#   'Position Weight': 2,
#   'Community': 161,
#   'Position': 'COUNCILOR'},
#  'AMOR MACALMA BAGARINO': {'Last Name': 'BAGARINO',
#   'Middle Name': 'MACALMA',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'JESSIE RICHARD ALBANO CALAPINI': {'Last Name': 'CALAPINI',
#   'Middle Name': 'ALBANO',
#   'Position Weight': 2,
#   'Community': 22,
#   'Position': 'COUNCILOR'},
#  'SAMUEL DOMINGO CALANO': {'Last Name': 'CALANO',
#   'Middle Name': 'DOMINGO',
#   'Position Weight': 2,
#   'Community': 10,
#   'Position': 'COUNCILOR'},
#  'BARTOLOME  ASUNCION': {'Last Name': 'ASUNCION',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 21,
#   'Position': 'COUNCILOR'},
#  'ASTOR MACALIPIS ASUNCION': {'Last Name': 'ASUNCION',
#   'Middle Name': 'MACALIPIS',
#   'Position Weight': 2,
#   'Community': 21,
#   'Position': 'COUNCILOR'},
#  'NOLASCO  PASCUA': {'Last Name': 'PASCUA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'MARIBEL  PASCUA': {'Last Name': 'PASCUA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'FERDINAND MACALMA PASCUA': {'Last Name': 'PASCUA',
#   'Middle Name': 'MACALMA',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'CHARITO  PASCUA': {'Last Name': 'PASCUA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'ARTHUR PAGUIRIGAN PASCUA': {'Last Name': 'PASCUA',
#   'Middle Name': 'PAGUIRIGAN',
#   'Position Weight': 2,
#   'Community': 3,
#   'Position': 'COUNCILOR'},
#  'ROGELIO DEMDEM PAMBID': {'Last Name': 'PAMBID',
#   'Middle Name': 'DEMDEM',
#   'Position Weight': 5,
#   'Community': 162,
#   'Position': 'MAYOR'},
#  'MICHAEL MARCOS KEON': {'Last Name': 'KEON',
#   'Middle Name': 'MARCOS',
#   'Position Weight': 2,
#   'Community': 12,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'ONOFRE AGUSTIN BAYAG': {'Last Name': 'BAYAG',
#   'Middle Name': 'AGUSTIN',
#   'Position Weight': 2,
#   'Community': 163,
#   'Position': 'COUNCILOR'},
#  'ROGERICK CAMBE BALBAG': {'Last Name': 'BALBAG',
#   'Middle Name': 'CAMBE',
#   'Position Weight': 2,
#   'Community': 19,
#   'Position': 'COUNCILOR'},
#  'EFREN SANTOS BUMILTAC GARCIA': {'Last Name': 'GARCIA',
#   'Middle Name': 'BUMILTAC',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'PASTOR AGUILA ARINGAY': {'Last Name': 'ARINGAY',
#   'Middle Name': 'AGUILA',
#   'Position Weight': 2,
#   'Community': 165,
#   'Position': 'COUNCILOR'},
#  'EDGAR SIBALI SUEB': {'Last Name': 'SUEB',
#   'Middle Name': 'SIBALI',
#   'Position Weight': 2,
#   'Community': 156,
#   'Position': 'COUNCILOR'},
#  'AVELARD IBARRA FRANCO CRISOSTOMO': {'Last Name': 'CRISOSTOMO',
#   'Middle Name': 'FRANCO',
#   'Position Weight': 2,
#   'Community': 5,
#   'Position': 'COUNCILOR'},
#  'DA VINCI MANUEL CRISOSTOMO': {'Last Name': 'CRISOSTOMO',
#   'Middle Name': 'MANUEL',
#   'Position Weight': 2,
#   'Community': 5,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'MARJORIE  BAQUIRAN': {'Last Name': 'BAQUIRAN',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 145,
#   'Position': 'COUNCILOR'},
#  'ROMMEL TAMAYO LABASAN': {'Last Name': 'LABASAN',
#   'Middle Name': 'TAMAYO',
#   'Position Weight': 2,
#   'Community': 13,
#   'Position': 'COUNCILOR'},
#  'REX CASTRO BENEMERITO': {'Last Name': 'BENEMERITO',
#   'Middle Name': 'CASTRO',
#   'Position Weight': 2,
#   'Community': 9,
#   'Position': 'COUNCILOR'},
#  'DANILO  BANCUD': {'Last Name': 'BANCUD',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 146,
#   'Position': 'COUNCILOR'},
#  'JUSTO AGCARRANG BANABA': {'Last Name': 'BANABA',
#   'Middle Name': 'AGCARRANG',
#   'Position Weight': 2,
#   'Community': 147,
#   'Position': 'COUNCILOR'},
#  'VICTOR AGULLANA CORPUZ': {'Last Name': 'CORPUZ',
#   'Middle Name': 'AGULLANA',
#   'Position Weight': 2,
#   'Community': 7,
#   'Position': 'COUNCILOR'},
#  'EVELYN MAULIT CORPUZ': {'Last Name': 'CORPUZ',
#   'Middle Name': 'MAULIT',
#   'Position Weight': 2,
#   'Community': 7,
#   'Position': 'COUNCILOR'},
#  'MATILDE KABIGTING HENSON': {'Last Name': 'HENSON',
#   'Middle Name': 'KABIGTING',
#   'Position Weight': 3,
#   'Community': 148,
#   'Position': 'VICE MAYOR'},
#  'FERDINAND  MARCOS': {'Last Name': 'MARCOS',
#   'Middle Name': '',
#   'Position Weight': 5,
#   'Community': 12,
#   'Position': 'GOVERNOR'},
#  'CRESCENTE NARCISO GARCIA': {'Last Name': 'GARCIA',
#   'Middle Name': 'NARCISO',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'RUBEN GUIANG TAROMA': {'Last Name': 'TAROMA',
#   'Middle Name': 'GUIANG',
#   'Position Weight': 2,
#   'Community': 149,
#   'Position': 'COUNCILOR'},
#  'YVONNE  RANADA': {'Last Name': 'RANADA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 150,
#   'Position': 'COUNCILOR'},
#  'ELSIE PATACSIL GARCES': {'Last Name': 'GARCES',
#   'Middle Name': 'PATACSIL',
#   'Position Weight': 2,
#   'Community': 151,
#   'Position': 'COUNCILOR'},
#  'WILFRED ALUPAY GACES': {'Last Name': 'GACES',
#   'Middle Name': 'ALUPAY',
#   'Position Weight': 5,
#   'Community': 152,
#   'Position': 'MAYOR'},
#  'DEIRDRE SADIAN RAGONJAN': {'Last Name': 'RAGONJAN',
#   'Middle Name': 'SADIAN',
#   'Position Weight': 2,
#   'Community': 26,
#   'Position': 'COUNCILOR'},
#  'NATHANIEL RUBEN DOMINGO TAYLAN': {'Last Name': 'TAYLAN',
#   'Middle Name': 'DOMINGO',
#   'Position Weight': 2,
#   'Community': 10,
#   'Position': 'COUNCILOR'},
#  'MARIA IMELDA  MARCOS': {'Last Name': 'MARCOS',
#   'Middle Name': '',
#   'Position Weight': 5,
#   'Community': 12,
#   'Position': 'MEMBER, HOUSE OF REPRESENTATIVES'},
#  'MARIANO FRANCIS MARCOS': {'Last Name': 'MARCOS',
#   'Middle Name': 'FRANCIS',
#   'Position Weight': 2,
#   'Community': 12,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'DIVINA GRACIA  BARLAHAN': {'Last Name': 'BARLAHAN',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 153,
#   'Position': 'COUNCILOR'},
#  'RODOLFO LAZO GARCIA': {'Last Name': 'GARCIA',
#   'Middle Name': 'LAZO',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'BERNARDO KU MARDERS': {'Last Name': 'MARDERS',
#   'Middle Name': 'KU',
#   'Position Weight': 2,
#   'Community': 11,
#   'Position': 'COUNCILOR'},
#  'JOEL REYES GARCIA': {'Last Name': 'GARCIA',
#   'Middle Name': 'REYES',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'JULIUS  RAGUAL': {'Last Name': 'RAGUAL',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 154,
#   'Position': 'COUNCILOR'},
#  'ALEJANDRO ACIDO RAGUDO': {'Last Name': 'RAGUDO',
#   'Middle Name': 'ACIDO',
#   'Position Weight': 2,
#   'Community': 155,
#   'Position': 'COUNCILOR'},
#  'JOCELYN  AREVALO': {'Last Name': 'AREVALO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 164,
#   'Position': 'COUNCILOR'},
#  'JO ANNE  ARZADON': {'Last Name': 'ARZADON',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 8,
#   'Position': 'COUNCILOR'},
#  'RIZAL. GALABAY VIERNES': {'Last Name': 'VIERNES',
#   'Middle Name': 'GALABAY',
#   'Position Weight': 2,
#   'Community': 7,
#   'Position': 'COUNCILOR'},
#  'RONY BALICAO GANAL': {'Last Name': 'GANAL',
#   'Middle Name': 'BALICAO',
#   'Position Weight': 2,
#   'Community': 181,
#   'Position': 'COUNCILOR'},
#  'EFREN PIEDAD TOMAS': {'Last Name': 'TOMAS',
#   'Middle Name': 'PIEDAD',
#   'Position Weight': 2,
#   'Community': 4,
#   'Position': 'COUNCILOR'},
#  'FAUSTINO DACUYCUY TOMAS': {'Last Name': 'TOMAS',
#   'Middle Name': 'DACUYCUY',
#   'Position Weight': 2,
#   'Community': 4,
#   'Position': 'COUNCILOR'},
#  'MA. ELENA  NALUPTA': {'Last Name': 'NALUPTA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 11,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'JESUS ROSARIO NALUPTA': {'Last Name': 'NALUPTA',
#   'Middle Name': 'ROSARIO',
#   'Position Weight': 5,
#   'Community': 11,
#   'Position': 'MAYOR'},
#  'RONALD ALLAN MARDERS NALUPTA': {'Last Name': 'NALUPTA',
#   'Middle Name': 'MARDERS',
#   'Position Weight': 2,
#   'Community': 11,
#   'Position': 'COUNCILOR'},
#  'JOSE ECHEVARRI TALAMAYAN': {'Last Name': 'TALAMAYAN',
#   'Middle Name': 'ECHEVARRI',
#   'Position Weight': 2,
#   'Community': 182,
#   'Position': 'COUNCILOR'},
#  'JOHN BONOAN VELASCO': {'Last Name': 'VELASCO',
#   'Middle Name': 'BONOAN',
#   'Position Weight': 2,
#   'Community': 15,
#   'Position': 'COUNCILOR'},
#  'IMELDA  MALAPIT': {'Last Name': 'MALAPIT',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 183,
#   'Position': 'COUNCILOR'},
#  'PHILIP CORPUS VELASCO': {'Last Name': 'VELASCO',
#   'Middle Name': 'CORPUS',
#   'Position Weight': 5,
#   'Community': 15,
#   'Position': 'MAYOR'},
#  'ADLAI  FACTORA': {'Last Name': 'FACTORA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 184,
#   'Position': 'COUNCILOR'},
#  'RODOLFO LLAPITAN VALDEZ': {'Last Name': 'VALDEZ',
#   'Middle Name': 'LLAPITAN',
#   'Position Weight': 3,
#   'Community': 25,
#   'Position': 'VICE MAYOR'},
#  'ALFREDO PAJINAG VALDEZ': {'Last Name': 'VALDEZ',
#   'Middle Name': 'PAJINAG',
#   'Position Weight': 5,
#   'Community': 25,
#   'Position': 'MAYOR'},
#  'DANILO CARRANZA FOZ': {'Last Name': 'FOZ',
#   'Middle Name': 'CARRANZA',
#   'Position Weight': 3,
#   'Community': 185,
#   'Position': 'VICE MAYOR'},
#  'JAMES RENTAR GAVINO': {'Last Name': 'GAVINO',
#   'Middle Name': 'RENTAR',
#   'Position Weight': 2,
#   'Community': 186,
#   'Position': 'COUNCILOR'},
#  'EMILIO SUBIA VISAYA': {'Last Name': 'VISAYA',
#   'Middle Name': 'SUBIA',
#   'Position Weight': 2,
#   'Community': 187,
#   'Position': 'COUNCILOR'},
#  'JUANITO  ESPEJO': {'Last Name': 'ESPEJO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 188,
#   'Position': 'COUNCILOR'},
#  'AMBROCIO  SORIANO': {'Last Name': 'SORIANO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 189,
#   'Position': 'COUNCILOR'},
#  'ERROL ACACIO RAMAJO': {'Last Name': 'RAMAJO',
#   'Middle Name': 'ACACIO',
#   'Position Weight': 3,
#   'Community': 190,
#   'Position': 'VICE MAYOR'},
#  'BISMARK ANGELO ARCANGEL QUIDANG': {'Last Name': 'QUIDANG',
#   'Middle Name': 'ARCANGEL',
#   'Position Weight': 2,
#   'Community': 191,
#   'Position': 'COUNCILOR'},
#  'PEDRO BAETIONG GALANG': {'Last Name': 'GALANG',
#   'Middle Name': 'BAETIONG',
#   'Position Weight': 3,
#   'Community': 192,
#   'Position': 'VICE MAYOR'},
#  'GINALINE ROMOTAP RANCHEZ': {'Last Name': 'RANCHEZ',
#   'Middle Name': 'ROMOTAP',
#   'Position Weight': 2,
#   'Community': 193,
#   'Position': 'COUNCILOR'},
#  'ALFREDO  REGIDOR': {'Last Name': 'REGIDOR',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 194,
#   'Position': 'COUNCILOR'},
#  'EDIMAR  UBASA': {'Last Name': 'UBASA',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 195,
#   'Position': 'COUNCILOR'},
#  'KENT RAGONJAN RAGUINDIN': {'Last Name': 'RAGUINDIN',
#   'Middle Name': 'RAGONJAN',
#   'Position Weight': 2,
#   'Community': 26,
#   'Position': 'COUNCILOR'},
#  'MICHAEL  FARINAS': {'Last Name': 'FARINAS',
#   'Middle Name': '',
#   'Position Weight': 5,
#   'Community': 27,
#   'Position': 'MAYOR'},
#  'ARNEL  FARINAS': {'Last Name': 'FARINAS',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 27,
#   'Position': 'COUNCILOR'},
#  'ESPERIDION  VIERNES': {'Last Name': 'VIERNES',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 7,
#   'Position': 'COUNCILOR'},
#  'ROLANDO RAGASA TOMAS': {'Last Name': 'TOMAS',
#   'Middle Name': 'RAGASA',
#   'Position Weight': 2,
#   'Community': 4,
#   'Position': 'COUNCILOR'},
#  'THOMAS NICOLAS TORRALBA': {'Last Name': 'TORRALBA',
#   'Middle Name': 'NICOLAS',
#   'Position Weight': 5,
#   'Community': 14,
#   'Position': 'MAYOR'},
#  'ROGER OANDASAN ARZADON': {'Last Name': 'ARZADON',
#   'Middle Name': 'OANDASAN',
#   'Position Weight': 2,
#   'Community': 8,
#   'Position': 'COUNCILOR'},
#  'CAROLINE ARZADON GARVIDA': {'Last Name': 'GARVIDA',
#   'Middle Name': 'ARZADON',
#   'Position Weight': 5,
#   'Community': 8,
#   'Position': 'MAYOR'},
#  'JOSEPH BALA ARZADON': {'Last Name': 'ARZADON',
#   'Middle Name': 'BALA',
#   'Position Weight': 3,
#   'Community': 8,
#   'Position': 'VICE MAYOR'},
#  'GUILLERMO ALBANO ASIS': {'Last Name': 'ASIS',
#   'Middle Name': 'ALBANO',
#   'Position Weight': 2,
#   'Community': 22,
#   'Position': 'COUNCILOR'},
#  'MICAELA ANGELA GARCIA ARQUILLO': {'Last Name': 'ARQUILLO',
#   'Middle Name': 'GARCIA',
#   'Position Weight': 2,
#   'Community': 0,
#   'Position': 'COUNCILOR'},
#  'CONSTANTE FRONDA DANCEL': {'Last Name': 'DANCEL',
#   'Middle Name': 'FRONDA',
#   'Position Weight': 2,
#   'Community': 1,
#   'Position': 'COUNCILOR'},
#  'WILSON CASTILLO SIMEON': {'Last Name': 'SIMEON',
#   'Middle Name': 'CASTILLO',
#   'Position Weight': 2,
#   'Community': 34,
#   'Position': 'COUNCILOR'},
#  'CLEMENTE  GERVACIO': {'Last Name': 'GERVACIO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 166,
#   'Position': 'COUNCILOR'},
#  'REYDA BARLAHAN TUGAS': {'Last Name': 'TUGAS',
#   'Middle Name': 'BARLAHAN',
#   'Position Weight': 2,
#   'Community': 167,
#   'Position': 'COUNCILOR'},
#  'JONATHAN OASAN TORRALBA': {'Last Name': 'TORRALBA',
#   'Middle Name': 'OASAN',
#   'Position Weight': 2,
#   'Community': 14,
#   'Position': 'COUNCILOR'},
#  'ROMAN SALVIEJO TORRALBA': {'Last Name': 'TORRALBA',
#   'Middle Name': 'SALVIEJO',
#   'Position Weight': 2,
#   'Community': 14,
#   'Position': 'COUNCILOR'},
#  'BERNARDO YAMONGAN FERNANDO': {'Last Name': 'FERNANDO',
#   'Middle Name': 'YAMONGAN',
#   'Position Weight': 2,
#   'Community': 168,
#   'Position': 'COUNCILOR'},
#  'FERDINAND  GANO': {'Last Name': 'GANO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 169,
#   'Position': 'COUNCILOR'},
#  'SHIRLEY  SIN': {'Last Name': 'SIN',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 170,
#   'Position': 'PROVINCIAL BOARD MEMBER'},
#  'RENE VILLA GASPAR': {'Last Name': 'GASPAR',
#   'Middle Name': 'VILLA',
#   'Position Weight': 3,
#   'Community': 171,
#   'Position': 'VICE MAYOR'},
#  'JUAN  SILVANO': {'Last Name': 'SILVANO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 172,
#   'Position': 'COUNCILOR'},
#  'JOY BANAGUI CARTE FERNANDEZ': {'Last Name': 'FERNANDEZ',
#   'Middle Name': 'CARTE',
#   'Position Weight': 5,
#   'Community': 23,
#   'Position': 'MAYOR'},
#  'RAMON MANA GAOAT': {'Last Name': 'GAOAT',
#   'Middle Name': 'MANA',
#   'Position Weight': 2,
#   'Community': 173,
#   'Position': 'COUNCILOR'},
#  'ANTONIO  YORO': {'Last Name': 'YORO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 24,
#   'Position': 'COUNCILOR'},
#  'GREGSON ESQUIVEL YORO': {'Last Name': 'YORO',
#   'Middle Name': 'ESQUIVEL',
#   'Position Weight': 2,
#   'Community': 24,
#   'Position': 'COUNCILOR'},
#  'CESAR MADRIAGA GALZOTE': {'Last Name': 'GALZOTE',
#   'Middle Name': 'MADRIAGA',
#   'Position Weight': 2,
#   'Community': 174,
#   'Position': 'COUNCILOR'},
#  'BONIFACIO  MADRID': {'Last Name': 'MADRID',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 175,
#   'Position': 'COUNCILOR'},
#  'ROGELIO DOMINGO GALLARDO': {'Last Name': 'GALLARDO',
#   'Middle Name': 'DOMINGO',
#   'Position Weight': 2,
#   'Community': 10,
#   'Position': 'COUNCILOR'},
#  'AMANDA ROSARIO RUIZ FLORES': {'Last Name': 'FLORES',
#   'Middle Name': 'RUIZ',
#   'Position Weight': 2,
#   'Community': 1,
#   'Position': 'COUNCILOR'},
#  'VILLAMOR  RAMELB': {'Last Name': 'RAMELB',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 176,
#   'Position': 'COUNCILOR'},
#  'PRIMO JAY  RAMOS': {'Last Name': 'RAMOS',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 177,
#   'Position': 'COUNCILOR'},
#  'JUAN  TUKIAD': {'Last Name': 'TUKIAD',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 178,
#   'Position': 'COUNCILOR'},
#  'QUIRICO GUERRERO ZAFARALLA': {'Last Name': 'ZAFARALLA',
#   'Middle Name': 'GUERRERO',
#   'Position Weight': 2,
#   'Community': 179,
#   'Position': 'COUNCILOR'},
#  'RODERICK  ERMITANIO': {'Last Name': 'ERMITANIO',
#   'Middle Name': '',
#   'Position Weight': 2,
#   'Community': 180,
#   'Position': 'COUNCILOR'},
#  'ARACELI DAVID DOMINGO': {'Last Name': 'DOMINGO',
#   'Middle Name': 'DAVID',
#   'Position Weight': 2,
#   'Community': 10,
#   'Position': 'COUNCILOR'}}

# %%
ln = df_unique_names["Last Name"].values
mn = df_unique_names["Middle Name"].values
weights = df_unique_names["Position Weight"].values

print(len(ln), len(mn), len(weights))
# Out:
# 245 245 245

# %%
df_unique_names
# Out:
#        Last Name First Name Middle Name   Position      Party  Year  \
# 191     BANGAOAN     LIBRES              COUNCILOR  LAKAS-CMD  2004
# 10103     EDROZO     ALIPIO              COUNCILOR  LAKAS-CMD  2004
# 10323    SANCHEZ     DENNIS     JAMBARO  COUNCILOR  LAKAS-CMD  2004
# 10357      SACPA      DANNY      TUGADE  COUNCILOR  LAKAS-CMD  2004
# 10364      SACRO        BOB     GOROSPE  COUNCILOR  LAKAS-CMD  2004
# ...          ...        ...         ...        ...        ...   ...
# 5925       RAMOS  PRIMO JAY              COUNCILOR        NPC  2004
# 5977      TUKIAD       JUAN              COUNCILOR        NPC  2004
# 6024   ZAFARALLA    QUIRICO    GUERRERO  COUNCILOR        IND  2004
# 6068   ERMITANIO   RODERICK              COUNCILOR        KBL  2004
# 17376    DOMINGO    ARACELI       DAVID  COUNCILOR        LDP  2004
#
#            Province    Region  Position Weight                   Full Name  \
# 191    ILOCOS NORTE  REGION I                2            LIBRES  BANGAOAN
# 10103  ILOCOS NORTE  REGION I                2              ALIPIO  EDROZO
# 10323  ILOCOS NORTE  REGION I                2      DENNIS JAMBARO SANCHEZ
# 10357  ILOCOS NORTE  REGION I                2          DANNY TUGADE SACPA
# 10364  ILOCOS NORTE  REGION I                2           BOB GOROSPE SACRO
# ...             ...       ...              ...                         ...
# 5925   ILOCOS NORTE  REGION I                2            PRIMO JAY  RAMOS
# 5977   ILOCOS NORTE  REGION I                2                JUAN  TUKIAD
# 6024   ILOCOS NORTE  REGION I                2  QUIRICO GUERRERO ZAFARALLA
# 6068   ILOCOS NORTE  REGION I                2         RODERICK  ERMITANIO
# 17376  ILOCOS NORTE  REGION I                2       ARACELI DAVID DOMINGO
#
#        Community
# 191          144
# 10103         28
# 10323        208
# 10357        209
# 10364        210
# ...          ...
# 5925         177
# 5977         178
# 6024         179
# 6068         180
# 17376         10
#
# [245 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122367 entries, 0 to 122366
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Last Name        122367 non-null  object
#  1   First Name       122367 non-null  object
#  2   Middle Name      108186 non-null  object
#  3   Position         122367 non-null  object
#  4   Party            121237 non-null  object
#  5   Year             122367 non-null  int64
#  6   Province         122367 non-null  object
#  7   Region           104233 non-null  object
#  8   Position Weight  122367 non-null  int64
#  9   Full Name        122367 non-null  object
#  10  Community        122367 non-null  int64
#  11  mask             122367 non-null  int32
# dtypes: int32(1), int64(3), object(8)
# memory usage: 10.7+ MB
